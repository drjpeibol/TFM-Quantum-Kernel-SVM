# %% [markdown]
# # Quantum Kernel Machine Learning
#
# The general task of machine learning is to find and study patterns in data. For many datasets, the datapoints are better understood in a higher dimensional feature space, through the use of a kernel function:
# $k(\vec{x}_i, \vec{x}_j) = \langle f(\vec{x}_i), f(\vec{x}_j) \rangle$
# where $k$ is the kernel function, $\vec{x}_i, \vec{x}_j$ are $n$ dimensional inputs, $f$ is a map from $n$-dimension to $m$-dimension space and $\langle a,b \rangle$ denotes the dot product. When considering finite data, a kernel function can be represented as a matrix:
# $K_{ij} = k(\vec{x}_i,\vec{x}_j)$.
#
# In quantum kernel machine learning, a quantum feature map $\phi(\vec{x})$ is used to map a classical feature vector $\vec{x}$ to a quantum Hilbert space, $| \phi(\vec{x})\rangle \langle \phi(\vec{x})|$, such that $K_{ij} = \left| \langle \phi^\dagger(\vec{x}_j)| \phi(\vec{x}_i) \rangle \right|^{2}$. See [_Supervised learning with quantum enhanced feature spaces_](https://arxiv.org/pdf/1804.11326.pdf) for more details.
#
# In this notebook, we use `qiskit` to calculate a kernel matrix using a quantum feature map, then use this kernel matrix in `scikit-learn` classification and clustering algorithms.

# %% [markdown]
# ### Conexión a instancia de IBM Quantum

# %%
import numpy as np# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator
import qiskit
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from typing import Optional, List, Union, Tuple
import numpy as np
from qiskit.circuit import QuantumCircuit
from qiskit.circuit.library.arithmetic.piecewise_linear_pauli_rotations import PiecewiseLinearPauliRotations
from qiskit import Aer
from qiskit.utils import QuantumInstance
from qiskit.algorithms import IterativeAmplitudeEstimation
from qiskit_finance.circuit.library import LogNormalDistribution
from numpy import random
from qiskit.converters.circuit_to_dag import circuit_to_dag
from qiskit.converters.dag_to_circuit import dag_to_circuit
from qiskit.compiler import transpile
from qiskit.exceptions import QiskitError
import matplotlib.pyplot as plt
from qiskit.utils import QuantumInstance
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute# Loading your IBM Quantum account(s)
#acceso = 'CSIC' # CSIC
acceso = 'EXTERNO' # Pablo
Backend_qubits = 10# Loading your IBM Quantum account(s)
IBMQ.load_account()
print (acceso)
if acceso == 'CSIC' :
# number of qubits to represent the uncertainty ***********************************************************************************************************
    numero_de_qbits_de_incertidumbre = 3
#**********************************************************************************************************************************************************
    IBMQ.load_account()
    provider = IBMQ.get_provider(hub='ibm-q-csic')
    provider.backends()
    from qiskit.providers.ibmq import least_busy
    backend = least_busy(provider.backends(filters=lambda b: b.configuration().n_qubits >= Backend_qubits and not b.configuration().simulator and b.status().operational==True))
    print (backend)
    sistema_cuantico = str(backend)
    print (sistema_cuantico)
else :
# number of qubits to represent the uncertainty ***********************************************************************************************************
    numero_de_qbits_de_incertidumbre = 3
#**********************************************************************************************************************************************************
# Loading your IBM Quantum account(s)
    provider = IBMQ.load_account()
    sistema_cuantico = 'ibmq_belem'
    backend = provider.get_backend(sistema_cuantico)
    print (sistema_cuantico)#provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2021-10-31 17:02:46,673: Credentials are already in use. The existing account in the session will be replaced.
# ibmqfactory.load_account:WARNING:2021-10-31 17:02:49,157: Credentials are already in use. The existing account in the session will be replaced.
# EXTERNO
# ibmq_belem

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.svm import SVC
from sklearn.cluster import SpectralClustering
from sklearn.metrics import normalized_mutual_info_score

from qiskit import BasicAer
from qiskit.circuit.library import ZZFeatureMap
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit_machine_learning.algorithms import QSVC
from qiskit_machine_learning.kernels import QuantumKernel
from qiskit_machine_learning.datasets import ad_hoc_data

seed = 12345
algorithm_globals.random_seed = seed

# %% [markdown]
# ## Classification
#
# For our classification example, we will use the _ad hoc dataset_ as described in [_Supervised learning with quantum enhanced feature spaces_](https://arxiv.org/pdf/1804.11326.pdf), and the `scikit-learn` [support vector machine](https://scikit-learn.org/stable/modules/svm.html) classification (`svc`) algorithm.

# %%
adhoc_dimension = 2
train_features, train_labels, test_features, test_labels, adhoc_total = ad_hoc_data(
    training_size=75,
    test_size=20,
    n=adhoc_dimension,
    gap=0.3,
    plot_data=False, one_hot=False, include_sample_total=True
)

plt.figure(figsize=(5, 5))
plt.ylim(0, 2 * np.pi)
plt.xlim(0, 2 * np.pi)
plt.imshow(np.asmatrix(adhoc_total).T, interpolation='nearest',
           origin='lower', cmap='RdBu', extent=[0, 2 * np.pi, 0, 2 * np.pi])

plt.scatter(train_features[np.where(train_labels[:] == 0), 0], train_features[np.where(train_labels[:] == 0), 1],
            marker='s', facecolors='w', edgecolors='b', label="A train")
plt.scatter(train_features[np.where(train_labels[:] == 1), 0], train_features[np.where(train_labels[:] == 1), 1],
            marker='o', facecolors='w', edgecolors='r', label="B train")
plt.scatter(test_features[np.where(test_labels[:] == 0), 0], test_features[np.where(test_labels[:] == 0), 1],
            marker='s', facecolors='b', edgecolors='w', label="A test")
plt.scatter(test_features[np.where(test_labels[:] == 1), 0], test_features[np.where(test_labels[:] == 1), 1],
            marker='o', facecolors='r', edgecolors='w', label="B test")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Ad hoc dataset for classification")

plt.show()

# %% [markdown]
# With our training and testing datasets ready, we set up the `QuantumKernel` class to calculate a kernel matrix using the [ZZFeatureMap](https://qiskit.org/documentation/stubs/qiskit.circuit.library.ZZFeatureMap.html), and the `BasicAer` `qasm_simulator` using 1024 shots.

# %%
adhoc_feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, 
                                 reps=2, entanglement='linear')

adhoc_backend = QuantumInstance(backend, shots=1024,
                                seed_simulator=seed, seed_transpiler=seed)

adhoc_kernel = QuantumKernel(feature_map=adhoc_feature_map, quantum_instance=adhoc_backend)

# %% [markdown]
# The `scikit-learn` `svc` algorithm allows us to define a [custom kernel](https://scikit-learn.org/stable/modules/svm.html#custom-kernels) in two ways: by providing the kernel as a callable function or by precomputing the kernel matrix. We can do either of these using the `QuantumKernel` class in `qiskit`.
#
# The following code gives the kernel as a callable function:

# %%
adhoc_svc = SVC(kernel=adhoc_kernel.evaluate)
adhoc_svc.fit(train_features, train_labels)
adhoc_score = adhoc_svc.score(test_features, test_labels)

print(f'Callable kernel classification test score: {adhoc_score}')
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: max_credits is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: seed_simulator is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# Job limit reached, waiting for job 617ecc59db752b866bd18221 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc5baa793ed65412a79b to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc5ddb752b54b8d18222 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc5eaa793e35d512a79c to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc60aa793e0f4a12a79d to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc769c7dc552bdacac62 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecc8f9c7dc594e1acac64 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecd98ce699ace526e9ebb to finish before submitting the next one.
# Job limit reached, waiting for job 617ecd9a355c9d4d99c5a386 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecd9bdb752bc32bd1822f to finish before submitting the next one.
# Job limit reached, waiting for job 617ecd9d51a002ebc2305b70 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecd9eabd2d33044e74483 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecdc49c7dc56be9acac71 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecddd9c7dc5bd5cacac72 to finish before submitting the next one.
# Job limit reached, waiting for job 617ecee6abd2d36c2ae7448a to finish before submitting the next one.
# Job limit reached, waiting for job 617ecee807a4a3c3157bff55 to finish before submitting the next one.
# Job limit reached, waiting for job 617eceea355c9d63a4c5a392 to finish before submitting the next one.
# Job limit reached, waiting for job 617eceebabd2d38391e7448b to finish before submitting the next one.
# Job limit reached, waiting for job 617eceed51a002239c305b7b to finish before submitting the next one.
# Job limit reached, waiting for job 617ecf049c7dc52d7aacac7c to finish before submitting the next one.
# Job limit reached, waiting for job 617ecf1d9c7dc54f44acac7d to finish before submitting the next one.
# Job limit reached, waiting for job 617ed02ece699a78c16e9ecd to finish before submitting the next one.
# Job limit reached, waiting for job 617ed02f07a4a3fa607bff5a to finish before submitting the next one.
# Job limit reached, waiting for job 617ed031e1429a4d48544c7c to finish before submitting the next one.
# Job limit reached, waiting for job 617ed0321394ee2bf10f17d5 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed0349c7dc51cf6acac80 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed04b355c9d83efc5a396 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed06451a0025819305b82 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed16ce1429ac989544c80 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed16daa793e08cc12a7bd to finish before submitting the next one.
# Job limit reached, waiting for job 617ed16f9c7dc51df4acac88 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed170355c9d73c0c5a3a1 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed172db752b37bbd18249 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed1891394ee26650f17dc to finish before submitting the next one.
# Job limit reached, waiting for job 617ed1a29c7dc59747acac8a to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2b4ce699a2c1e6e9edd to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2b7ce699a452a6e9ede to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2b81394ee41e40f17e2 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2b9db752befa0d18252 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2bb9c7dc59f21acac90 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2d1e1429a67f0544c89 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed2eb07a4a340dc7bff6a to finish before submitting the next one.
# Job limit reached, waiting for job 617ed3f851a0028dbd305b8f to finish before submitting the next one.
# Job limit reached, waiting for job 617ed3face699a37536e9edf to finish before submitting the next one.
# Job limit reached, waiting for job 617ed3fc355c9d78f1c5a3b0 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed3fde1429a72ac544c91 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed3feabd2d34345e7449e to finish before submitting the next one.
# Job limit reached, waiting for job 617ed415e1429ace7d544c92 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed42fe1429a95ed544c93 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed55b07a4a32b277bff7d to finish before submitting the next one.
# Job limit reached, waiting for job 617ed55d1394ee6eee0f17f1 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed55fce699a78416e9ee5 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed560db752b63abd1825c to finish before submitting the next one.
# Job limit reached, waiting for job 617ed563abd2d348e2e744a6 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed579ce699a7c1e6e9ee6 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed5ac355c9d5fdbc5a3b6 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6c81394eea3f80f17fa to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6ca51a0026ca4305b9c to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6ccaa793e1e2e12a7d7 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6ce355c9d1adac5a3b9 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6cfabd2d39a17e744ad to finish before submitting the next one.
# Job limit reached, waiting for job 617ed6ef07a4a31de67bff86 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed708aa793e3edf12a7d8 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed82051a0027dca305ba4 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed8221394ee08120f1803 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed82407a4a390957bff8c to finish before submitting the next one.
# Job limit reached, waiting for job 617ed82507a4a3611c7bff8d to finish before submitting the next one.
# Job limit reached, waiting for job 617ed82651a002f8e3305ba5 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed83e07a4a37bf57bff8e to finish before submitting the next one.
# Job limit reached, waiting for job 617ed858db752b31d4d18267 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed971abd2d34e1be744b4 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed973db752b50ead1826b to finish before submitting the next one.
# Job limit reached, waiting for job 617ed975ce699a9bda6e9ef9 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed9761394ee38d50f180a to finish before submitting the next one.
# Job limit reached, waiting for job 617ed978e1429a7993544ca6 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed98e355c9dfb5ac5a3c1 to finish before submitting the next one.
# Job limit reached, waiting for job 617ed9b51394ee27490f180c to finish before submitting the next one.
# Job limit reached, waiting for job 617edae99c7dc500aeacacb5 to finish before submitting the next one.
# Job limit reached, waiting for job 617edaebabd2d31dc0e744b7 to finish before submitting the next one.
# Job limit reached, waiting for job 617edaeeaa793e040f12a7eb to finish before submitting the next one.
# Job limit reached, waiting for job 617edaef9c7dc57006acacb6 to finish before submitting the next one.
# Job limit reached, waiting for job 617edaf151a0025b91305baa to finish before submitting the next one.
# Job limit reached, waiting for job 617edb0d355c9d2e94c5a3c9 to finish before submitting the next one.
# Job limit reached, waiting for job 617edb279c7dc516adacacb7 to finish before submitting the next one.
# Job limit reached, waiting for job 617edd0fdb752bbcd1d1827b to finish before submitting the next one.
# Job limit reached, waiting for job 617edd129c7dc57317acacbd to finish before submitting the next one.
# Job limit reached, waiting for job 617edd1307a4a31ecb7bffa1 to finish before submitting the next one.
# Job limit reached, waiting for job 617edd1507a4a398857bffa2 to finish before submitting the next one.
# Job limit reached, waiting for job 617edd17e1429a5370544cb8 to finish before submitting the next one.
# Job limit reached, waiting for job 617edd2dce699a2cfb6e9f11 to finish before submitting the next one.
# Job limit reached, waiting for job 617edd4651a002283a305bb3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ede5407a4a39d777bffaa to finish before submitting the next one.
# Job limit reached, waiting for job 617ede5607a4a328fd7bffab to finish before submitting the next one.
# Job limit reached, waiting for job 617ede57e1429a4cf8544cba to finish before submitting the next one.
# Job limit reached, waiting for job 617ede59db752b645cd18280 to finish before submitting the next one.
# Job limit reached, waiting for job 617ede5babd2d35d03e744bf to finish before submitting the next one.
# Job limit reached, waiting for job 617ede72e1429a8f78544cbb to finish before submitting the next one.
# Job limit reached, waiting for job 617ede8b07a4a3170e7bffac to finish before submitting the next one.
# Job limit reached, waiting for job 617edf9b1394ee72e70f1821 to finish before submitting the next one.
# Job limit reached, waiting for job 617edf9d9c7dc53d96acacc7 to finish before submitting the next one.
# Job limit reached, waiting for job 617edf9faa793e63e612a7fd to finish before submitting the next one.
# Job limit reached, waiting for job 617edfa051a0028631305bb6 to finish before submitting the next one.
# Job limit reached, waiting for job 617edfa2ce699a457a6e9f1b to finish before submitting the next one.
# Job limit reached, waiting for job 617edfc751a0022f82305bba to finish before submitting the next one.
# Job limit reached, waiting for job 617edfe01394eebf220f1822 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee0f4ce699ab7636e9f22 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee0f6db752ba053d1828b to finish before submitting the next one.
# Job limit reached, waiting for job 617ee0f79c7dc59fecacacca to finish before submitting the next one.
# Job limit reached, waiting for job 617ee0f9abd2d313d9e744c6 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee0fbaa793ed0b912a800 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee1121394eec8f10f1829 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee12c355c9d3704c5a3e0 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee23fdb752b98ded18290 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee2419c7dc59988acacd1 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee24207a4a366147bffba to finish before submitting the next one.
# Job limit reached, waiting for job 617ee2449c7dc52bcbacacd2 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee246ce699a14626e9f29 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee25cabd2d386f7e744d1 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee2769c7dc5512aacacd3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee395355c9d2f10c5a3f0 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee3961394ee53920f1839 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee398db752b012dd18298 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee399aa793e2d6c12a810 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee39bdb752b1508d1829a to finish before submitting the next one.
# Job limit reached, waiting for job 617ee3b11394ee53670f183b to finish before submitting the next one.
# Job limit reached, waiting for job 617ee3ca07a4a36f7c7bffbf to finish before submitting the next one.
# Job limit reached, waiting for job 617ee4d4db752b404ed1829f to finish before submitting the next one.
# Job limit reached, waiting for job 617ee4d59c7dc51433acace0 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee4d71394ee32890f1845 to finish before submitting the next one.
# Callable kernel classification test score: 1.0

# %% [markdown]
# The following code precomputes and plots the training and testing kernel matrices before providing them to the `scikit-learn` `svc` algorithm:

# %%
adhoc_matrix_train = adhoc_kernel.evaluate(x_vec=train_features)
adhoc_matrix_test = adhoc_kernel.evaluate(x_vec=test_features,
                                          y_vec=train_features)

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(np.asmatrix(adhoc_matrix_train),
              interpolation='nearest', origin='upper', cmap='Blues')
axs[0].set_title("Ad hoc training kernel matrix")
axs[1].imshow(np.asmatrix(adhoc_matrix_test),
              interpolation='nearest', origin='upper', cmap='Reds')
axs[1].set_title("Ad hoc testing kernel matrix")
plt.show()

adhoc_svc = SVC(kernel='precomputed')
adhoc_svc.fit(adhoc_matrix_train, train_labels)
adhoc_score = adhoc_svc.score(adhoc_matrix_test, test_labels)

print(f'Precomputed kernel classification test score: {adhoc_score}')
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: max_credits is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: seed_simulator is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# Job limit reached, waiting for job 617ee5b9e1429a552e544cd9 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5baabd2d36edae744dd to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5bc355c9deec4c5a3fc to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5bd1394eef4740f184c to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5bf355c9d0a95c5a3fd to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5d51394ee01b50f184e to finish before submitting the next one.
# Job limit reached, waiting for job 617ee5efabd2d374c9e744df to finish before submitting the next one.
# Job limit reached, waiting for job 617ee70707a4a334727bffd3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee709ce699a52466e9f44 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee70b1394ee911d0f1852 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee70ce1429ac296544cde to finish before submitting the next one.
# Job limit reached, waiting for job 617ee70ee1429a8a9d544cdf to finish before submitting the next one.
# Job limit reached, waiting for job 617ee725db752b2392d182a5 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee73f07a4a3749c7bffd4 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee85907a4a39f427bffdb to finish before submitting the next one.
# Job limit reached, waiting for job 617ee85be1429a3f65544ce4 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee85cdb752b0e60d182ad to finish before submitting the next one.
# Job limit reached, waiting for job 617ee85e1394eee9d20f1856 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee85fce699a7bad6e9f47 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee8761394ee5a460f1857 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee89051a002f1d1305be3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9a251a0026a4b305bea to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9a3e1429a7fab544ceb to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9a59c7dc5b716acacf3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9a7355c9dddb2c5a40d to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9a907a4a3d4b07bffe3 to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9bf1394ee11f10f185b to finish before submitting the next one.
# Job limit reached, waiting for job 617ee9d9ce699a5fd06e9f4e to finish before submitting the next one.
# Job limit reached, waiting for job 617eeafd07a4a364457bffeb to finish before submitting the next one.
# Job limit reached, waiting for job 617eeafe07a4a349757bffec to finish before submitting the next one.
# Job limit reached, waiting for job 617eeb009c7dc55b59acacfa to finish before submitting the next one.
# Job limit reached, waiting for job 617eeb02abd2d33103e744f2 to finish before submitting the next one.
# Job limit reached, waiting for job 617eeb04aa793ecfdc12a82b to finish before submitting the next one.
# Job limit reached, waiting for job 617eeb2307a4a397eb7bffed to finish before submitting the next one.
# Job limit reached, waiting for job 617eeb3dabd2d30dc5e744f4 to finish before submitting the next one.
# Job limit reached, waiting for job 617eec94ce699a859a6e9f56 to finish before submitting the next one.
# Job limit reached, waiting for job 617eec961394ee06b40f1865 to finish before submitting the next one.
# Job limit reached, waiting for job 617eec981394ee42340f1866 to finish before submitting the next one.
# Job limit reached, waiting for job 617eec999c7dc58706acad02 to finish before submitting the next one.
# Job limit reached, waiting for job 617eec9a9c7dc57632acad03 to finish before submitting the next one.
# Job limit reached, waiting for job 617eecd5e1429a9885544cf7 to finish before submitting the next one.
# Job limit reached, waiting for job 617eecf0e1429a5303544cf8 to finish before submitting the next one.
# Job limit reached, waiting for job 617eedfd1394ee34910f186a to finish before submitting the next one.
# Job limit reached, waiting for job 617eedffaa793eaf3512a839 to finish before submitting the next one.
# Job limit reached, waiting for job 617eee00aa793e22b412a83a to finish before submitting the next one.
# Job limit reached, waiting for job 617eee02abd2d31d08e744f8 to finish before submitting the next one.
# Job limit reached, waiting for job 617eee0407a4a384ac7bfffb to finish before submitting the next one.
# Job limit reached, waiting for job 617eee2807a4a3d8f37bfffc to finish before submitting the next one.
# Job limit reached, waiting for job 617eee43aa793e88b112a83f to finish before submitting the next one.
# Job limit reached, waiting for job 617eef6707a4a3f4d37c0006 to finish before submitting the next one.
# Job limit reached, waiting for job 617eef69ce699a67c86e9f62 to finish before submitting the next one.
# Job limit reached, waiting for job 617eef6b07a4a3fc187c0007 to finish before submitting the next one.
# Job limit reached, waiting for job 617eef6cdb752bbc5ed182d2 to finish before submitting the next one.
# Job limit reached, waiting for job 617eef6e9c7dc5140dacad14 to finish before submitting the next one.
# Job limit reached, waiting for job 617eef871394eef82c0f1873 to finish before submitting the next one.
# Job limit reached, waiting for job 617eefa1abd2d373d7e744ff to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0af51a00250d5305c03 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0b1ce699a137c6e9f6c to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0b3db752be802d182da to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0b451a002a3ad305c04 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0b6e1429a162c544d0e to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0ccce699a0da66e9f6d to finish before submitting the next one.
# Job limit reached, waiting for job 617ef0e6abd2d3049de74507 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef209e1429a032b544d11 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef20aabd2d354ede7450d to finish before submitting the next one.
# Job limit reached, waiting for job 617ef20cdb752b6bc4d182e2 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef20dce699a34cd6e9f77 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef20fce699a13ea6e9f78 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef22651a0020e97305c0e to finish before submitting the next one.
# Job limit reached, waiting for job 617ef25107a4a3451d7c0012 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef35d1394ee7d410f1886 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef35fe1429aae8c544d13 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef3611394ee1e710f1887 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef3621394ee287d0f1888 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef364abd2d3b270e74510 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef3841394ee66dc0f1889 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef39ece699a1ecd6e9f7f to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4afce699acadf6e9f83 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4b1abd2d35caae7451b to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4b2ce699a329e6e9f84 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4b5ce699aefd96e9f85 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4b7355c9d89e5c5a441 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef4eadb752b13bed182ee to finish before submitting the next one.
# Job limit reached, waiting for job 617ef504db752b023fd182ef to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6aa07a4a3d33c7c0028 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6ab9c7dc56806acad32 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6acdb752b4704d182f8 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6aeaa793e469512a86c to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6b007a4a3e1477c0029 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6c807a4a346757c002a to finish before submitting the next one.
# Job limit reached, waiting for job 617ef6e1aa793e683312a86e to finish before submitting the next one.
# Job limit reached, waiting for job 617ef7ecabd2d3256ee7452c to finish before submitting the next one.
# Job limit reached, waiting for job 617ef7edce699a83d26e9f8d to finish before submitting the next one.
# Job limit reached, waiting for job 617ef7ef51a002709b305c2a to finish before submitting the next one.
# Job limit reached, waiting for job 617ef7f1e1429a0414544d27 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef7f39c7dc5906cacad35 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef808db752b0db1d18304 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef821355c9d68f4c5a450 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef93aaa793e9a2912a877 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef93b9c7dc53036acad3d to finish before submitting the next one.
# Job limit reached, waiting for job 617ef93dabd2d32262e7452f to finish before submitting the next one.
# Job limit reached, waiting for job 617ef93fabd2d342f9e74530 to finish before submitting the next one.
# Job limit reached, waiting for job 617ef941db752bb77cd1830d to finish before submitting the next one.
# Job limit reached, waiting for job 617ef963ce699a45e46e9f9b to finish before submitting the next one.
# Job limit reached, waiting for job 617ef97de1429a236b544d34 to finish before submitting the next one.
# Job limit reached, waiting for job 617efa87e1429a5564544d3b to finish before submitting the next one.
# Job limit reached, waiting for job 617efa8907a4a32b807c0044 to finish before submitting the next one.
# Job limit reached, waiting for job 617efa8baa793e66cd12a87d to finish before submitting the next one.
# Job limit reached, waiting for job 617efa8daa793e459812a87e to finish before submitting the next one.
# Job limit reached, waiting for job 617efa8eaa793e569112a87f to finish before submitting the next one.
# Job limit reached, waiting for job 617efaaa355c9d10b9c5a464 to finish before submitting the next one.
# Job limit reached, waiting for job 617efac31394ee80290f18ba to finish before submitting the next one.
# Job limit reached, waiting for job 617efbce9c7dc5f488acad4d to finish before submitting the next one.
# Job limit reached, waiting for job 617efbd051a002d5b8305c4c to finish before submitting the next one.
# Job limit reached, waiting for job 617efbd2e1429aecc3544d41 to finish before submitting the next one.
# Job limit reached, waiting for job 617efbd451a002b5ed305c4d to finish before submitting the next one.
# Job limit reached, waiting for job 617efbd6355c9d52d6c5a46c to finish before submitting the next one.
# Job limit reached, waiting for job 617efbebce699a72056e9faf to finish before submitting the next one.
# Job limit reached, waiting for job 617efc05abd2d3dbbee74542 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd25db752b28efd18328 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd279c7dc546cfacad53 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd2951a0025f6c305c54 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd2b07a4a321387c004c to finish before submitting the next one.
# Job limit reached, waiting for job 617efd2e51a0025e5e305c56 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd43abd2d30bd7e74545 to finish before submitting the next one.
# Job limit reached, waiting for job 617efd5d9c7dc51851acad54 to finish before submitting the next one.
# Job limit reached, waiting for job 617efe7a51a0029087305c60 to finish before submitting the next one.
# Job limit reached, waiting for job 617efe7caa793e440c12a88d to finish before submitting the next one.
# Job limit reached, waiting for job 617efe7ee1429accf7544d4f to finish before submitting the next one.
# Precomputed kernel classification test score: 1.0

# %% [markdown]
# `qiskit` also contains the `qsvc` class that extends the `sklearn svc` class, that can be used as follows:

# %%
qsvc = QSVC(quantum_kernel=adhoc_kernel)
qsvc.fit(train_features, train_labels)
qsvc_score = qsvc.score(test_features, test_labels)

print(f'QSVC classification test score: {qsvc_score}')
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: max_credits is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# /opt/conda/lib/python3.8/site-packages/qiskit/utils/run_circuits.py:695: UserWarning: seed_simulator is not a recognized runtime option and may be ignored by the backend.
#   return backend.run(circuits, **run_kwargs)
# Job limit reached, waiting for job 617effc651a0029001305c68 to finish before submitting the next one.
# Job limit reached, waiting for job 617effc81394ee1e290f18dd to finish before submitting the next one.
# Job limit reached, waiting for job 617effcbaa793e5f1c12a89a to finish before submitting the next one.
# Job limit reached, waiting for job 617effcd07a4a3c8347c005c to finish before submitting the next one.
# Job limit reached, waiting for job 617effcf07a4a39a4e7c005d to finish before submitting the next one.
# Job limit reached, waiting for job 617effe59c7dc5670cacad5d to finish before submitting the next one.
# Job limit reached, waiting for job 617f0008abd2d3e25ee74553 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0177ce699a65a76e9fd4 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0178e1429a2cb6544d62 to finish before submitting the next one.
# Job limit reached, waiting for job 617f017a1394ee4c270f18e8 to finish before submitting the next one.
# Job limit reached, waiting for job 617f017d1394ee2a6d0f18e9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f017fdb752b0202d18346 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0194db752bf34ad18347 to finish before submitting the next one.
# Job limit reached, waiting for job 617f01b707a4a3368a7c0066 to finish before submitting the next one.
# Job limit reached, waiting for job 617f02cd51a0025a42305c7b to finish before submitting the next one.
# Job limit reached, waiting for job 617f02cfabd2d37fe9e74567 to finish before submitting the next one.
# Job limit reached, waiting for job 617f02d1355c9d3150c5a48f to finish before submitting the next one.
# Job limit reached, waiting for job 617f02d31394ee87570f18f9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f02d4aa793e488112a8b0 to finish before submitting the next one.
# Job limit reached, waiting for job 617f02ecabd2d3777ce74569 to finish before submitting the next one.
# Job limit reached, waiting for job 617f030507a4a3098a7c006f to finish before submitting the next one.
# Job limit reached, waiting for job 617f046ace699a36ad6e9fe9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f046caa793e5f6712a8b7 to finish before submitting the next one.
# Job limit reached, waiting for job 617f046ece699a09836e9fea to finish before submitting the next one.
# Job limit reached, waiting for job 617f0470abd2d39f20e74573 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0471e1429a6927544d73 to finish before submitting the next one.
# Job limit reached, waiting for job 617f048807a4a386ea7c0075 to finish before submitting the next one.
# Job limit reached, waiting for job 617f04addb752b7ee0d1835e to finish before submitting the next one.
# Job limit reached, waiting for job 617f063107a4a3ba737c0080 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0633ce699a6cc26e9ff6 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0635ce699aa6d66e9ff7 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0637ce699a05e16e9ff8 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0638db752b598cd1836a to finish before submitting the next one.
# Job limit reached, waiting for job 617f065c51a0027d9b305c8d to finish before submitting the next one.
# Job limit reached, waiting for job 617f067551a0020bc3305c8f to finish before submitting the next one.
# Job limit reached, waiting for job 617f07811394ee1beb0f1914 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0783abd2d3d510e74586 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0785e1429a6b2c544d85 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0786abd2d358e3e74587 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0788aa793edb5312a8d0 to finish before submitting the next one.
# Job limit reached, waiting for job 617f079e9c7dc523c3acad90 to finish before submitting the next one.
# Job limit reached, waiting for job 617f07bfabd2d33315e74589 to finish before submitting the next one.
# Job limit reached, waiting for job 617f08cbe1429a5d39544d8b to finish before submitting the next one.
# Job limit reached, waiting for job 617f08cdabd2d34fcfe74593 to finish before submitting the next one.
# Job limit reached, waiting for job 617f08cf355c9d1cf9c5a4b1 to finish before submitting the next one.
# Job limit reached, waiting for job 617f08d0e1429a4166544d8c to finish before submitting the next one.
# Job limit reached, waiting for job 617f08d2db752b2ca1d18379 to finish before submitting the next one.
# Job limit reached, waiting for job 617f08eae1429a9342544d8d to finish before submitting the next one.
# Job limit reached, waiting for job 617f0903db752b2849d1837a to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a0ce1429aed2a544d95 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a0eabd2d3ef63e7459a to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a109c7dc5494bacad9e to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a12ce699a18ea6ea011 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a14ce699a602d6ea012 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a31db752b696bd18383 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0a49abd2d38239e7459d to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c09e1429a3990544da1 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c0bdb752b3965d1838e to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c0d9c7dc562b7acadb2 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c0f51a0029430305caa to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c11355c9d9bbec5a4c8 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c309c7dc559cfacadb5 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0c6eabd2d36d5fe745b1 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0ddfabd2d3d48de745ba to finish before submitting the next one.
# Job limit reached, waiting for job 617f0de19c7dc58904acadc1 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0de39c7dc58817acadc2 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0de51394eef3fa0f1942 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0de71394ee30900f1943 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0dfd51a002024f305cb5 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0e169c7dc57166acadc5 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f27abd2d346f8e745c8 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f29ce699a50b66ea033 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f2a355c9d05fec5a4df to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f2d07a4a31bb77c00b5 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f2e51a0023c99305cc0 to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f44e1429a84e7544dba to finish before submitting the next one.
# Job limit reached, waiting for job 617f0f5eaa793e527412a8ff to finish before submitting the next one.
# Job limit reached, waiting for job 617f10679c7dc5913dacaddc to finish before submitting the next one.
# Job limit reached, waiting for job 617f106907a4a363fa7c00be to finish before submitting the next one.
# Job limit reached, waiting for job 617f106aabd2d38413e745d3 to finish before submitting the next one.
# Job limit reached, waiting for job 617f106c51a002a78b305cc6 to finish before submitting the next one.
# Job limit reached, waiting for job 617f106ece699a71396ea03c to finish before submitting the next one.
# Job limit reached, waiting for job 617f1085db752b0333d183b3 to finish before submitting the next one.
# Job limit reached, waiting for job 617f109fce699a59616ea03f to finish before submitting the next one.
# Job limit reached, waiting for job 617f124751a0023f8c305ccf to finish before submitting the next one.
# Job limit reached, waiting for job 617f1248aa793e53ec12a911 to finish before submitting the next one.
# Job limit reached, waiting for job 617f124a9c7dc508f0acade9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f124cabd2d31c52e745e3 to finish before submitting the next one.
# Job limit reached, waiting for job 617f124eaa793e842e12a912 to finish before submitting the next one.
# Job limit reached, waiting for job 617f126f51a002409c305cd0 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1289355c9dcee5c5a4f9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1395db752b060dd183d1 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1397aa793e7c0a12a923 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1399ce699a29966ea054 to finish before submitting the next one.
# Job limit reached, waiting for job 617f139babd2d3ea7ce745ea to finish before submitting the next one.
# Job limit reached, waiting for job 617f139caa793efec612a925 to finish before submitting the next one.
# Job limit reached, waiting for job 617f13bd51a0023e79305cdd to finish before submitting the next one.
# Job limit reached, waiting for job 617f13d7e1429a2269544dd2 to finish before submitting the next one.
# Job limit reached, waiting for job 617f14e4aa793ede2312a930 to finish before submitting the next one.
# Job limit reached, waiting for job 617f14e5355c9d3affc5a50c to finish before submitting the next one.
# Job limit reached, waiting for job 617f14e7aa793e28ad12a931 to finish before submitting the next one.
# Job limit reached, waiting for job 617f14e9e1429af822544dda to finish before submitting the next one.
# Job limit reached, waiting for job 617f14ea1394ee05ca0f1977 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1502abd2d380c8e745f6 to finish before submitting the next one.
# Job limit reached, waiting for job 617f151ece699a13d86ea05e to finish before submitting the next one.
# Job limit reached, waiting for job 617f1664355c9ddf77c5a518 to finish before submitting the next one.
# Job limit reached, waiting for job 617f16679c7dc523caacae04 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1669355c9da9aec5a519 to finish before submitting the next one.
# Job limit reached, waiting for job 617f166b1394ee8efe0f1985 to finish before submitting the next one.
# Job limit reached, waiting for job 617f166de1429ab805544dec to finish before submitting the next one.
# Job limit reached, waiting for job 617f168251a002e7ed305cf4 to finish before submitting the next one.
# Job limit reached, waiting for job 617f169babd2d34af2e74603 to finish before submitting the next one.
# Job limit reached, waiting for job 617f180851a0021211305d00 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1809ce699afb0c6ea070 to finish before submitting the next one.
# Job limit reached, waiting for job 617f180b9c7dc571b6acae12 to finish before submitting the next one.
# Job limit reached, waiting for job 617f180d1394ee535c0f198f to finish before submitting the next one.
# Job limit reached, waiting for job 617f180f07a4a372277c00f0 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1829e1429aa519544df9 to finish before submitting the next one.
# Job limit reached, waiting for job 617f186751a0026b27305d05 to finish before submitting the next one.
# Job limit reached, waiting for job 617f19fa355c9df909c5a537 to finish before submitting the next one.
# Job limit reached, waiting for job 617f19fb9c7dc578deacae1f to finish before submitting the next one.
# Job limit reached, waiting for job 617f19fde1429a789b544e07 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1a0051a0023521305d12 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1a02aa793e4e3e12a954 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1a1751a0022f47305d14 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1a30abd2d3718ae74621 to finish before submitting the next one.
# Job limit reached, waiting for job 617f1b36db752b2c65d1840e to finish before submitting the next one.
# Job limit reached, waiting for job 617f1b38e1429a23ed544e0b to finish before submitting the next one.
# Job limit reached, waiting for job 617f1b3ae1429a0a87544e0c to finish before submitting the next one.
# QSVC classification test score: 1.0

# %% [markdown]
# ## Clustering
#
# For our clustering example, we will again use the _ad hoc dataset_ as described in [_Supervised learning with quantum enhanced feature spaces_](https://arxiv.org/pdf/1804.11326.pdf), and the `scikit-learn` `spectral` clustering algorithm.
#
# We will regenerate the dataset with a larger gap between the two classes, and as clustering is an unsupervised machine learning task, we don't need a test sample.

# %%
adhoc_dimension = 2
train_features, train_labels, test_features, test_labels, adhoc_total = ad_hoc_data(
    training_size=25,
    test_size=0,
    n=adhoc_dimension,
    gap=0.6,
    plot_data=False, one_hot=False, include_sample_total=True
)

plt.figure(figsize=(5, 5))
plt.ylim(0, 2 * np.pi)
plt.xlim(0, 2 * np.pi)
plt.imshow(np.asmatrix(adhoc_total).T, interpolation='nearest',
           origin='lower', cmap='RdBu', extent=[0, 2 * np.pi, 0, 2 * np.pi])
plt.scatter(train_features[np.where(train_labels[:] == 0), 0], train_features[np.where(train_labels[:] == 0), 1],
            marker='s', facecolors='w', edgecolors='b', label="A")
plt.scatter(train_features[np.where(train_labels[:] == 1), 0], train_features[np.where(train_labels[:] == 1), 1],
            marker='o', facecolors='w', edgecolors='r', label="B")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Ad hoc dataset for clustering")

plt.show()

# %% [markdown]
# We again set up the `QuantumKernel` class to calculate a kernel matrix using the [ZZFeatureMap](https://qiskit.org/documentation/stubs/qiskit.circuit.library.ZZFeatureMap.html), and the BasicAer `qasm_simulator` using 1024 shots.

# %%
adhoc_feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, 
                                 reps=2, entanglement='linear')

adhoc_backend = QuantumInstance(BasicAer.get_backend('qasm_simulator'), shots=1024,
                                seed_simulator=seed, seed_transpiler=seed)

adhoc_kernel = QuantumKernel(feature_map=adhoc_feature_map, quantum_instance=adhoc_backend)

# %% [markdown]
# The scikit-learn spectral clustering algorithm allows us to define a [custom kernel] in two ways: by providing the kernel as a callable function or by precomputing the kernel matrix. Using the QuantumKernel class in qiskit, we can only use the latter.
#
# The following code precomputes and plots the kernel matrices before providing it to the scikit-learn spectral clustering algorithm, and scoring the labels using normalized mutual information, since we a priori know the class labels.

# %%
adhoc_matrix = adhoc_kernel.evaluate(x_vec=train_features)

plt.figure(figsize=(5, 5))
plt.imshow(np.asmatrix(adhoc_matrix), interpolation='nearest', origin='upper', cmap='Greens')
plt.title("Ad hoc clustering kernel matrix")
plt.show()

adhoc_spectral = SpectralClustering(2, affinity="precomputed")
cluster_labels = adhoc_spectral.fit_predict(adhoc_matrix)
cluster_score = normalized_mutual_info_score(cluster_labels, train_labels)

print(f'Clustering score: {cluster_score}')
# Out:
# Clustering score: 0.8782063702756282

# %% [markdown]
# `scikit-learn` has other algorithms that can use a precomputed kernel matrix, here are a few:
#
# - [Agglomerative clustering](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html)
# - [Support vector regression](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)
# - [Ridge regression](https://scikit-learn.org/stable/modules/generated/sklearn.kernel_ridge.KernelRidge.html)
# - [Gaussian process regression](https://scikit-learn.org/stable/modules/gaussian_process.html)
# - [Principal component analysis](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.KernelPCA.html)

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/aqua/__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.18.3</td></tr><tr><td><code>qiskit-aer</code></td><td>0.9.1</td></tr><tr><td><code>qiskit-ignis</code></td><td>0.6.0</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.17.0</td></tr><tr><td><code>qiskit-aqua</code></td><td>0.9.5</td></tr><tr><td><code>qiskit</code></td><td>0.31.0</td></tr><tr><td><code>qiskit-nature</code></td><td>0.2.2</td></tr><tr><td><code>qiskit-finance</code></td><td>0.2.1</td></tr><tr><td><code>qiskit-optimization</code></td><td>0.2.3</td></tr><tr><td><code>qiskit-machine-learning</code></td><td>0.2.1</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.8.10 | packaged by conda-forge | (default, May 11 2021, 07:01:05)
# [GCC 9.3.0]</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>8</td></tr><tr><td>Memory (Gb)</td><td>31.400043487548828</td></tr><tr><td colspan='2'>Sun Oct 31 22:44:10 2021 UTC</td></tr></table>
# <div style='width: 100%; background-color:#d5d9e0;padding-left: 10px; padding-bottom: 10px; padding-right: 10px; padding-top: 5px'><h3>This code is a part of Qiskit</h3><p>&copy; Copyright IBM 2017, 2021.</p><p>This code is licensed under the Apache License, Version 2.0. You may<br>obtain a copy of this license in the LICENSE.txt file in the root directory<br> of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.<p>Any modifications or derivative works of this code must retain this<br>copyright notice, and modified files need to carry a notice indicating<br>that they have been altered from the originals.</p></div>
